# %%
import numpy as np

# %%
v = np.array([1,2,3,4])
v
# Out:
# array([1, 2, 3, 4])

# %%
M = np.array([[3,4], [5,6]])
print(M)
# Out:
# [[3 4]
#  [5 6]]

# %%
type(M)
# Out:
# numpy.ndarray

# %%
type(v)
# Out:
# numpy.ndarray

# %%
v.shape
# Out:
# (4,)

# %%
M.shape
# Out:
# (2, 2)

# %%
M.size
# Out:
# 4

# %%
v.size
# Out:
# 4

# %%
np.size()
