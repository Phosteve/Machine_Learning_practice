# %%
import numpy as np
np.set_printoptions(3, suppress=True)
m= np.array([1,2,3,4])
m
# Out:
# array([1, 2, 3, 4])

# %%
my_list = [1,3,5,6]
v = np.array(my_list)
v

# %%
M = np.array([[1,2], [3,4]])
print(M)

# %%
type(v)

# %%
v.shape

# %%
M.shape
