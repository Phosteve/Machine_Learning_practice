# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.8.2'

# %%
X = tf.range(-100, 100, 4)
X
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
from tensorflow.keras.utils import plo
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-b9814ff77337> in <module>()
#       1
#       2
# ----> 3 from tensorflow.keras.utils import plo
#
# ImportError: cannot import name 'plo' from 'tensorflow.keras.utils' (/usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/utils/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Make labels for the dataset
y = X + 10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
# Visualize the data
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %% [markdown]
# ### The 3 sets...

# %%
# check the length of how many samples wee have
len(X)
# Out:
# 50

# %%
# split the data into train and test set
X_train = X[:40]# first 40 are training samples (80% of the data)
y_train = y[:40]
X_test =  X[40:] # last 10 are testing samples (20%)
y_test = y[40:]

# %% [markdown]
# ### Tracking your experiments
# one really good habit in machine learning modelling is to track the results of your eperiments.
# And when doing so, it can be tedious if you're running lots of eperiments.
# Luckily, there are tools to help us!

# %% [markdown]
# ### Saving our models

# %%
# Set the random seed
tf.random.set_seed(42)

# 1. Create the model
model_2 = tf.keras.Sequential([
  tf.keras.layers.Dense(10, input_shape = [1]),
  tf.keras.layers.Dense(1)
])

# 2. Compile the model
model_2.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=["mse"])

# 3. Fit the model
model_2.fit(X_train, y_train, epochs= 100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 9ms/step - loss: 27.4058 - mse: 1084.1482
# Epoch 2/100
# 2/2 [==============================] - 0s 6ms/step - loss: 24.6339 - mse: 777.9203
# Epoch 3/100
# 2/2 [==============================] - 0s 5ms/step - loss: 29.8935 - mse: 1334.8955
# Epoch 4/100
# 2/2 [==============================] - 0s 8ms/step - loss: 27.4055 - mse: 1106.8035
# Epoch 5/100
# 2/2 [==============================] - 0s 7ms/step - loss: 14.9463 - mse: 281.1077
# Epoch 6/100
# 2/2 [==============================] - 0s 6ms/step - loss: 11.8819 - mse: 168.6621
# Epoch 7/100
# 2/2 [==============================] - 0s 11ms/step - loss: 11.1988 - mse: 151.3509
# Epoch 8/100
# 2/2 [==============================] - 0s 4ms/step - loss: 11.0910 - mse: 160.3745
# Epoch 9/100
# 2/2 [==============================] - 0s 6ms/step - loss: 40.4763 - mse: 2586.0090
# Epoch 10/100
# 2/2 [==============================] - 0s 10ms/step - loss: 27.8688 - mse: 1094.4382
# ...

# %%
y_preds_2 = model_2.predict(X_test)
plot_predictions(predictions=y_preds_2)

# %% [markdown]
# there two main formats we can save our models too

# %%
model_2.save("best_model_savedModel_fomat")

# %%
# Save model using the HDF5 format
model_2.save("best_model_HDF5_format.h5")

# %% [markdown]
# ## Loading in a saved model

# %%
loaded_SavedModel_format =tf.keras.models.load_model("best_model_SavedModel_format"
loaded_SavedModel_format.summary()

# %%
# Make a bigger dataset
X=tf.range(-100, 100, 4)
X

# %%
y= X+10
y

# %%
# Visualize the data
import matplotlib.pyplot as plt
plt.scatter(X, y)

# %%
# Check the length of how many samples we have
len(X)

# %%
### The 3 sets...
# split the data into train and test data

X_train=X[:40]
y_train=y[:40]
X_test=X[40:]
y_test=y[40:]

len(X_train), len(X_test), len(y_train), len(y_test)

# %% [markdown]
# ### Visualizing the data
# Now we've got our data in trainning and test sets..lets visualize it again1

# %%
plt.figure(figsize=(10, 7))
# Plot training data in blue
plt.scatter(X_train, y_train, c="b", label="Training data")
# Plot test data in green
plt.scatter(X_test, y_test, c="g", label="Testing data")
# Show a legend
plt.legend();

# %%
# Let's have a look at how to builld a neural network for our data

# 1. Create a model
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1, input_shape=[1])

])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# 3. Fit the model
model.fit(X_train, y_train, epochs=100);

# %%
X[0], y[0]

# %%
,model.summary()

# %%
tf.random.set_seed(42)
model= tf.keras.Sequential([
  tf.keras.layers.Dense(1, input_shape=[1])

])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])
# 3. Fit the model
model.fit(X_train, y_train, epochs=100)

# %%
model.summary()

# %%
# Set the seed
tf.random.set_seed(42)

# 1. Create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(4, input_shape=[1])

])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# 3. Fit the model
model.fit(X_train, y_train, epochs=100)

# %%
model.summary()

# %%
from tensorflow.keras.utils import plot_model
plot_model(model=model, show_shape)
