# %%
import numpy as np
np.set_printoptions(3, suppress=True)

# %% [markdown]
# coonverting Python list
# using functions thst are dedicated to generating numpy arrays, such as arange, linspace etc.

# %%
my_list = [1,2,3,4]
v = np.array(my_list)
v
# Out:
# array([1, 2, 3, 4])

# %%
M = np.array([[1,2],[3,4],[5,6]])
M
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# The v and M objects are both of the type ndarray that the numpy module provides.

# %%
type(v), type(M)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %% [markdown]
# The difference between the v and M arrays is only thier shapes. We can get information about the shape of an array by using the ndarray.
