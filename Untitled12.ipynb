# %%
import tensorflow as tf
from tensorflow import keras
tf.__version__
# Out:
# '2.8.2'

# %%
X = tf.range(-100, 100, 4)
X
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
y = X+10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y)

# %%
len(X)
# Out:
# 50

# %%
X_train = X[:40]
y_train = y[:40]
X_test = X[40:]
y_test = y[40:]

len(X_train), len(X_test), len(y_train),len(y_test)
# Out:
# (40, 10, 40, 10)

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_train, y_train, c="b", label = "Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.legend()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(3, input_shape=[1])

])
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])
model.fit(X_train, y_train, epochs=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c6ff430878e1> in <module>()
# ----> 1 model = tf.keras.Sequential([
#       2     tf.keras.layers.Dense(3, input_shape=[1])
#       3
#       4 ])
#       5 model.compile(loss=tf.keras.losses.mae,
#
# NameError: name 'tf' is not defined

# %%
model.summary()

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(20, input_shape=[1], name="'input_layer"),
  tf.keras.layers.Dense(1, name="output_layer")
], name="model_1")
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# %%
model.summary()

# %%
from tensorflow.keras.utils import plot_model
plot_model()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-985f7c7e70f6> in <module>()
# ----> 1 plot_model()
#
# TypeError: plot_model() missing 1 required positional argument: 'model'
